# %%
#Write a Python Program to check if a Number is Positive, Negative or Zero?
a=float(input("enter a number : "))
if a==0:
    print("Zero")
elif a>0:
    print("Number is Positive")
else:
    print("Number is Negative")
# Out:
# enter a number : 1
# Number is Positive

# %%
#Write a Python Program to check if a Number is Odd or Even
a=int(input("enter a number : "))
if a%2==0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# enter a number : 11
# Number is odd

# %%
#Write a Python Program to check Leap Year
year=int(input("Enter a year : "))
if (year%4)==0:
    print("Leap year")
elif (year%100)==0:
    print("Year is not a leap year")
elif (year%400)==0:
    print("Year is leap year")
else:
    print("Year is not a leap year")
# Out:
# Enter a year : 2028
# Leap year

# %%
#Write a Python Program to check Prime Number?
num=int(input("enter a number : "))
if num>1:
    for i in range(2,num):
        if (num%i)==0:
            print("number is not a prime number")
            break
    else:
        print("Prime number")
else:
    print("Number is not  a Prime number")
# Out:
# enter a number : 11
# Prime number

# %%
#Write a Python Program to print all Prime Numbers in an Interval of 1-10000?
lower=1
upper=1000

for num in range(lower,upper+1):
    if num>1:
        for i in range(2,num):
            if (num%i)==0:
                break
        else:
            print("Prime numbers in an Interval of 1-10000 is ", num)
# Out:
# Prime numbers in an Interval of 1-10000 is  2
# Prime numbers in an Interval of 1-10000 is  3
# Prime numbers in an Interval of 1-10000 is  5
# Prime numbers in an Interval of 1-10000 is  7
# Prime numbers in an Interval of 1-10000 is  11
# Prime numbers in an Interval of 1-10000 is  13
# Prime numbers in an Interval of 1-10000 is  17
# Prime numbers in an Interval of 1-10000 is  19
# Prime numbers in an Interval of 1-10000 is  23
# Prime numbers in an Interval of 1-10000 is  29
# Prime numbers in an Interval of 1-10000 is  31
# Prime numbers in an Interval of 1-10000 is  37
# Prime numbers in an Interval of 1-10000 is  41
# Prime numbers in an Interval of 1-10000 is  43
# Prime numbers in an Interval of 1-10000 is  47
# Prime numbers in an Interval of 1-10000 is  53
# Prime numbers in an Interval of 1-10000 is  59
# Prime numbers in an Interval of 1-10000 is  61
# Prime numbers in an Interval of 1-10000 is  67
# Prime numbers in an Interval of 1-10000 is  71
# Prime numbers in an Interval of 1-10000 is  73
# Prime numbers in an Interval of 1-10000 is  79
# Prime numbers in an Interval of 1-10000 is  83
# Prime numbers in an Interval of 1-10000 is  89
# Prime numbers in an Interval of 1-10000 is  97
# Prime numbers in an Interval of 1-10000 is  101
# Prime numbers in an Interval of 1-10000 is  103
# Prime numbers in an Interval of 1-10000 is  107
# Prime numbers in an Interval of 1-10000 is  109
# Prime numbers in an Interval of 1-10000 is  113
# Prime numbers in an Interval of 1-10000 is  127
# Prime numbers in an Interval of 1-10000 is  131
# Prime numbers in an Interval of 1-10000 is  137
# Prime numbers in an Interval of 1-10000 is  139
# Prime numbers in an Interval of 1-10000 is  149
# Prime numbers in an Interval of 1-10000 is  151
# Prime numbers in an Interval of 1-10000 is  157
# Prime numbers in an Interval of 1-10000 is  163
# Prime numbers in an Interval of 1-10000 is  167
# Prime numbers in an Interval of 1-10000 is  173
# Prime numbers in an Interval of 1-10000 is  179
# Prime numbers in an Interval of 1-10000 is  181
# Prime numbers in an Interval of 1-10000 is  191
# Prime numbers in an Interval of 1-10000 is  193
# Prime numbers in an Interval of 1-10000 is  197
# Prime numbers in an Interval of 1-10000 is  199
# Prime numbers in an Interval of 1-10000 is  211
# Prime numbers in an Interval of 1-10000 is  223
# Prime numbers in an Interval of 1-10000 is  227
# Prime numbers in an Interval of 1-10000 is  229
# Prime numbers in an Interval of 1-10000 is  233
# Prime numbers in an Interval of 1-10000 is  239
# Prime numbers in an Interval of 1-10000 is  241
# Prime numbers in an Interval of 1-10000 is  251
# Prime numbers in an Interval of 1-10000 is  257
# Prime numbers in an Interval of 1-10000 is  263
# Prime numbers in an Interval of 1-10000 is  269
# Prime numbers in an Interval of 1-10000 is  271
# Prime numbers in an Interval of 1-10000 is  277
# Prime numbers in an Interval of 1-10000 is  281
# Prime numbers in an Interval of 1-10000 is  283
# Prime numbers in an Interval of 1-10000 is  293
# Prime numbers in an Interval of 1-10000 is  307
# Prime numbers in an Interval of 1-10000 is  311
# Prime numbers in an Interval of 1-10000 is  313
# Prime numbers in an Interval of 1-10000 is  317
# Prime numbers in an Interval of 1-10000 is  331
# Prime numbers in an Interval of 1-10000 is  337
# Prime numbers in an Interval of 1-10000 is  347
# Prime numbers in an Interval of 1-10000 is  349
# Prime numbers in an Interval of 1-10000 is  353
# Prime numbers in an Interval of 1-10000 is  359
# Prime numbers in an Interval of 1-10000 is  367
# Prime numbers in an Interval of 1-10000 is  373
# Prime numbers in an Interval of 1-10000 is  379
# Prime numbers in an Interval of 1-10000 is  383
# Prime numbers in an Interval of 1-10000 is  389
# Prime numbers in an Interval of 1-10000 is  397
# Prime numbers in an Interval of 1-10000 is  401
# Prime numbers in an Interval of 1-10000 is  409
# Prime numbers in an Interval of 1-10000 is  419
# Prime numbers in an Interval of 1-10000 is  421
# Prime numbers in an Interval of 1-10000 is  431
# Prime numbers in an Interval of 1-10000 is  433
# Prime numbers in an Interval of 1-10000 is  439
# Prime numbers in an Interval of 1-10000 is  443
# Prime numbers in an Interval of 1-10000 is  449
# Prime numbers in an Interval of 1-10000 is  457
# Prime numbers in an Interval of 1-10000 is  461
# Prime numbers in an Interval of 1-10000 is  463
# Prime numbers in an Interval of 1-10000 is  467
# Prime numbers in an Interval of 1-10000 is  479
# Prime numbers in an Interval of 1-10000 is  487
# Prime numbers in an Interval of 1-10000 is  491
# Prime numbers in an Interval of 1-10000 is  499
# Prime numbers in an Interval of 1-10000 is  503
# Prime numbers in an Interval of 1-10000 is  509
# Prime numbers in an Interval of 1-10000 is  521
# Prime numbers in an Interval of 1-10000 is  523
# Prime numbers in an Interval of 1-10000 is  541
# Prime numbers in an Interval of 1-10000 is  547
# Prime numbers in an Interval of 1-10000 is  557
# Prime numbers in an Interval of 1-10000 is  563
# Prime numbers in an Interval of 1-10000 is  569
# Prime numbers in an Interval of 1-10000 is  571
# Prime numbers in an Interval of 1-10000 is  577
# Prime numbers in an Interval of 1-10000 is  587
# Prime numbers in an Interval of 1-10000 is  593
# Prime numbers in an Interval of 1-10000 is  599
# Prime numbers in an Interval of 1-10000 is  601
# Prime numbers in an Interval of 1-10000 is  607
# Prime numbers in an Interval of 1-10000 is  613
# Prime numbers in an Interval of 1-10000 is  617
# Prime numbers in an Interval of 1-10000 is  619
# Prime numbers in an Interval of 1-10000 is  631
# Prime numbers in an Interval of 1-10000 is  641
# Prime numbers in an Interval of 1-10000 is  643
# Prime numbers in an Interval of 1-10000 is  647
# Prime numbers in an Interval of 1-10000 is  653
# Prime numbers in an Interval of 1-10000 is  659
# Prime numbers in an Interval of 1-10000 is  661
# Prime numbers in an Interval of 1-10000 is  673
# Prime numbers in an Interval of 1-10000 is  677
# Prime numbers in an Interval of 1-10000 is  683
# Prime numbers in an Interval of 1-10000 is  691
# Prime numbers in an Interval of 1-10000 is  701
# Prime numbers in an Interval of 1-10000 is  709
# Prime numbers in an Interval of 1-10000 is  719
# Prime numbers in an Interval of 1-10000 is  727
# Prime numbers in an Interval of 1-10000 is  733
# Prime numbers in an Interval of 1-10000 is  739
# Prime numbers in an Interval of 1-10000 is  743
# Prime numbers in an Interval of 1-10000 is  751
# Prime numbers in an Interval of 1-10000 is  757
# Prime numbers in an Interval of 1-10000 is  761
# Prime numbers in an Interval of 1-10000 is  769
# Prime numbers in an Interval of 1-10000 is  773
# Prime numbers in an Interval of 1-10000 is  787
# Prime numbers in an Interval of 1-10000 is  797
# Prime numbers in an Interval of 1-10000 is  809
# Prime numbers in an Interval of 1-10000 is  811
# Prime numbers in an Interval of 1-10000 is  821
# Prime numbers in an Interval of 1-10000 is  823
# Prime numbers in an Interval of 1-10000 is  827
# Prime numbers in an Interval of 1-10000 is  829
# Prime numbers in an Interval of 1-10000 is  839
# Prime numbers in an Interval of 1-10000 is  853
# Prime numbers in an Interval of 1-10000 is  857
# Prime numbers in an Interval of 1-10000 is  859
# Prime numbers in an Interval of 1-10000 is  863
# Prime numbers in an Interval of 1-10000 is  877
# Prime numbers in an Interval of 1-10000 is  881
# Prime numbers in an Interval of 1-10000 is  883
# Prime numbers in an Interval of 1-10000 is  887
# Prime numbers in an Interval of 1-10000 is  907
# Prime numbers in an Interval of 1-10000 is  911
# Prime numbers in an Interval of 1-10000 is  919
# Prime numbers in an Interval of 1-10000 is  929
# Prime numbers in an Interval of 1-10000 is  937
# Prime numbers in an Interval of 1-10000 is  941
# Prime numbers in an Interval of 1-10000 is  947
# Prime numbers in an Interval of 1-10000 is  953
# Prime numbers in an Interval of 1-10000 is  967
# Prime numbers in an Interval of 1-10000 is  971
# Prime numbers in an Interval of 1-10000 is  977
# Prime numbers in an Interval of 1-10000 is  983
# Prime numbers in an Interval of 1-10000 is  991
# Prime numbers in an Interval of 1-10000 is  997
